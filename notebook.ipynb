# %%
import pandas as pd 

df = pd.read_csv("data/vlearn-pack/chatlog/tutor_turns.csv")

# %%
df.head(30)
# Out:
#    turn_id   period cohort_hint       asked_at_vn student lecture_code  \
# 0   T00001  history          K3  2026-07-22 18:00   S0140          D01
# 1   T00002  history          K3  2026-07-22 18:03   S0140          D02
# 2   T00003  history          K3  2026-07-22 18:04   S0140          D02
# 3   T00004  history          K3  2026-07-22 18:19   S0140          D01
# 4   T00005  history          K3  2026-07-22 19:00   S0140          D01
# 5   T00006  history          K3  2026-07-22 19:00   S0674          D01
# 6   T00007  history          K3  2026-07-22 19:00   S0674          D01
# 7   T00008  history          K3  2026-07-22 19:02   S0140          D02
# 8   T00009  history          K3  2026-07-22 19:13   S0140          D01
# 9   T00010  history          K3  2026-07-22 22:53   S0674          D01
# 10  T00011  history          K3  2026-07-23 10:09   S0674          D01
# 11  T00012  history          K3  2026-07-23 11:38   S0674          D02
# ...

# %%
df["student_question"][26]
# Out:
# '(Trang 3, đoạn được chọn: "tóm tắt ý")\ntóm tắt ý '

# %%
df["tutor_reply"][26]
# Out:
# 'Rất tiếc là mình hiện chưa tra cứu được nội dung cụ thể của **trang 3** trong bộ slide này qua hệ thống tìm kiếm. Có thể trang này chứa hình ảnh hoặc định dạng mà công cụ tìm kiếm chưa quét được nội dung văn bản.\n\nĐể mình có thể hỗ trợ tóm tắt chính xác nhất, bạn có thể chia sẻ giúp mình tiêu đề của trang đó hoặc một vài dòng nội dung chính được không? Mình sẽ giúp bạn tổng hợp các ý quan trọng ngay!'
